# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

np.random.seed(101)
tf.random.set_seed(101)

# %%
x = np.linspace(0,50,50)
y = np.linspace(0,50,50)

x += np.random.uniform(-4,4,50)
y += np.random.uniform(-4,4,50)

n = len(x)

# %%
# Plot of Training Data
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Training Data")
plt.show()

# %%
X = tf.placeholder("float")
Y = tf.placeholder("float")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\ismar\OneDrive - Institut Teknologi Sepuluh Nopember\Kuliah\S2\Semester 2\Eldas\Program\img_regression\tf_regression.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ismar/OneDrive%20-%20Institut%20Teknologi%20Sepuluh%20Nopember/Kuliah/S2/Semester%202/Eldas/Program/img_regression/tf_regression.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> X = tf.placeholder("float")
#       <a href='vscode-notebook-cell:/c%3A/Users/ismar/OneDrive%20-%20Institut%20Teknologi%20Sepuluh%20Nopember/Kuliah/S2/Semester%202/Eldas/Program/img_regression/tf_regression.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> Y = tf.placeholder("float")
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'
